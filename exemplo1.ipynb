# %%
import os
os.system('cls')
import pandas as pd 
import numpy as np 
import matplotlib as plt



try: 
    print('Obtendo dados')

    ENDERECO_DADOS = 'https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv'

    df_isp = pd.read_csv(ENDERECO_DADOS, sep=';', encoding='iso-8859-1')

    display(df_isp.columns)


except Exception as e:
    print(f'Erro ao obter dados: {e}')
    exit()
# Out:
# Obtendo dados
# Index(['cisp', 'mes', 'ano', 'mes_ano', 'aisp', 'risp', 'munic', 'mcirc',
#        'regiao', 'hom_doloso', 'lesao_corp_morte', 'latrocinio', 'cvli',
#        'hom_por_interv_policial', 'letalidade_violenta', 'tentat_hom',
#        'lesao_corp_dolosa', 'estupro', 'hom_culposo', 'lesao_corp_culposa',
#        'roubo_transeunte', 'roubo_celular', 'roubo_em_coletivo', 'roubo_rua',
#        'roubo_veiculo', 'roubo_carga', 'roubo_comercio', 'roubo_residencia',
#        'roubo_banco', 'roubo_cx_eletronico', 'roubo_conducao_saque',
#        'roubo_apos_saque', 'roubo_bicicleta', 'outros_roubos', 'total_roubos',
#        'furto_veiculos', 'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
# ...

# %%
try: 
    df_roubos_veiculos = df_isp[['cisp', 'mes', 'ano', 'munic', 'regiao', 'roubo_veiculo']]

    

except Exception as e:
    print(f'Erro ao obter dados: {e}')
    exit()

# %%
# calculando os quartis


try: 
    array_roubos_veiculos = np.array(df_roubos_veiculos['roubo_veiculo'])

    total = np.sum(array_roubos_veiculos)
    media = np.mean(array_roubos_veiculos)
    mediana = np.median(array_roubos_veiculos)

# imprimindo os resultados
    print(f'Total de roubos de veículos: {total}')
    print(f'Média de roubos de veículos: {media}')
    print(f'Mediana de roubos de veículos: {mediana}')

# quartis
    
    q1 = np.quantile(array_roubos_veiculos, 0.25, method='weibull')
    q3 = np.quantile(array_roubos_veiculos, 0.75, method='weibull')
    iqr = q3 - q1

    print(f'Q1: {q1}')
    print(f'Q3: {q3}')
    print(f'IQR: {iqr}')
    

except Exception as e:
    print(f'Erro ao obter dados: {e}')
    exit()
# Out:
# Total de roubos de veículos: 683038
# Média de roubos de veículos: 19.29703921347045
# Mediana de roubos de veículos: 4.0
# Q1: 0.0
# Q3: 24.0
# IQR: 24.0

# %%
# criando coluna nova, adicioando identificadores
# concatena a nova coluna no dataframe

try: 
# criando a nova coluna
    df_roubos_veiculos['flag'] = np.where(df_roubos_veiculos['roubo_veiculo'] <= q1, 'menos', np.where(df_roubos_veiculos['roubo_veiculo'] >= q3, 'mais', 'mais ou menos'))

    display(df_roubos_veiculos)

# salvando o dataframe
    df_roubos_veiculos.to_csv('roubos_veiculos.csv', index=False, sep=';', encoding='iso-8859-1')

    print('Arquivo salvo com sucesso')

except Exception as e:
    print(f'Erro ao obter dados: {e}')
    exit()
# Out:
# C:\Users\51134552024.01\AppData\Local\Temp\ipykernel_1752\1200333848.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_roubos_veiculos['flag'] = np.where(df_roubos_veiculos['roubo_veiculo'] <= q1, 'menos', np.where(df_roubos_veiculos['roubo_veiculo'] >= q3, 'mais', 'mais ou menos'))
#        cisp  mes   ano                 munic    regiao  roubo_veiculo  \
# 0         1    1  2003        Rio de Janeiro   Capital              5
# 1         4    1  2003        Rio de Janeiro   Capital              9
# 2         5    1  2003        Rio de Janeiro   Capital             11
# 3         6    1  2003        Rio de Janeiro   Capital             27
# 4         7    1  2003        Rio de Janeiro   Capital             23
# ...
